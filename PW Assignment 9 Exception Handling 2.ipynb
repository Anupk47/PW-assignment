# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %%
#In Python, all built-in exceptions are derived from the BaseException class, and more commonly from its subclass Exception. 
#When creating custom exceptions, we inherit from the Exception class to ensure our custom exception integrates with Python’s exception-handling framework
#example
class CustomeERROR(Exception):
    pass
try:
    raise CustomeERROR("Something Wrong")
except CustomeERROR as e:
    print(e)
# Out:
# Something Wrong

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
#python has a built in hierarchy for all exceptions. All errors like Zerodivisionerror, indexerror
#are organized under a parent class called baseexception

def print_hierarchy(cls,indent=0):
    print(" " * indent + cls.__name__)
    for subclass in cls.__subclasses__():
        print_hierarchy(subclass, indent + 2)

print_hierarchy(BaseException)
# Out:
# BaseException
#   BaseExceptionGroup
#     ExceptionGroup
#   Exception
#     ArithmeticError
#       FloatingPointError
#       OverflowError
#       ZeroDivisionError
#         DivisionByZero
#         DivisionUndefined
#       DecimalException
#         Clamped
#         Rounded
#           Underflow
#           Overflow
#         Inexact
#           Underflow
#           Overflow
#         Subnormal
#           Underflow
#         DivisionByZero
#         FloatOperation
#         InvalidOperation
#           ConversionSyntax
#           DivisionImpossible
#           DivisionUndefined
#           InvalidContext
#     AssertionError
#     AttributeError
#       FrozenInstanceError
#     BufferError
#     EOFError
#       IncompleteReadError
#     ImportError
#       ModuleNotFoundError
#         PackageNotFoundError
#       ZipImportError
#     LookupError
#       IndexError
#       KeyError
#         NoSuchKernel
#         UnknownBackend
#       CodecRegistryError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %%
#ArithmeticError is a base class for all errors that occur in numeric calculations. Some subclasses include:
#ZeroDivisionError
#OverflowError
#FloatingpointError
#example 1 Zerodivisionerror:
a = 5 / 0 #raises zero division error
#example 2 Overflowerror:
import math
print(math.expo(1000)) #raises math range error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 6
#       1 #ArithmeticError is a base class for all errors that occur in numeric calculations. Some subclasses include:
#       2 #ZeroDivisionError
#       3 #OverflowError
#       4 #FloatingpointError
#       5 #example 1 Zerodivisionerror:
# ----> 6 a = 5 / 0 #raises zero division error
#       7 #example 2 Overflowerror:
#       8 import math
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %%
#lookuperror is a base class for errors raised when a lookup operation like accessing a list, dictionary, or string fails
#it helps in grouping such errors
#example 
my_dict = {"name": "Anup"}
#print(my_dict["age"])
#raises a keyerror: "age"

#example2
my_list = [1,2,3]
#print(my_list[5]) 
#raises an indexerror : list index out of range

#using Lookuperror we can catch both
try:
    print(my_dict["age"])
except LookupError as e: 
    print("lookup error: ",e)
# Out:
# lookup error:  'age'

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %%
#ImportError
# it is raised when an import statement fails to find or load a module or its attribute
import non_existing_module

#moduleNotFOundError
#it is a subclass of import errkr that specifically occurs when the module itself is not found
from math import cube
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 3
#       1 #ImportError
#       2 # it is raised when an import statement fails to find or load a module or its attribute
# ----> 3 import non_existing_module
#       5 #moduleNotFOundError
#       6 #it is a subclass of import errkr that specifically occurs when the module itself is not found
#       7 from math import cube
#
# ModuleNotFoundError: No module named 'non_existing_module'

# %% [markdown]
# Q6. List down some best practices for exception handling in Python.

# %%
#1. Use specific exceptions instead of a general except: block
#2. Use finally for cleanup actions like closing files or connections
#3. create custom exceptions for clarity in large applications
#4. Avoid catching BaseExceptions, which includes system-exiting exceptions
#5. Use with statement for resource management like for files
